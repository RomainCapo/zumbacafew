# %%
import lyricsgenius
genius = lyricsgenius.Genius("")
artist = genius.search_artist("Kaaris", max_songs=5, sort="popularity")
print(artist.songs)
# Out:
# Searching for songs by Kaaris...
#
# Song 1: "Zoo"
# Song 2: "Or Noir"
# Song 3: "Tchoin"
# Song 4: "Sevrak"
# Song 5: "Bouchon de liège"
#
# Reached user-specified song limit (5).
# Done. Found 5 songs.
# [('Zoo', 'Kaaris'), ('Or Noir', 'Kaaris'), ('Tchoin', 'Kaaris'), ('Sevrak', 'Kaaris'), ('Bouchon de liège', 'Kaaris')]

# %%
from PIL import Image
import requests
from io import BytesIO

response = requests.get(artist.image_url)
img = Image.open(BytesIO(response.content))

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=447x447 at 0x19F3F559370>

# %%
song = genius.search_song("Tchoin", artist.name)
print(song.lyrics)
# Out:
# Searching for "Tchoin" by Kaaris...
# Done.
# [Intro]
# Double X on the track, bitch!
# Zongo
# Tchoin, tchoin, tchoin
# Tchoin, tchoin, tchoin
#
# [Refrain]
# La go là c'est p'têtre une fille bien
# Mais on préfère les tchoins, tchoins, tchoins
# La go là c'est p'têtre une fille bien
# Mais on préfère les tchoins, tchoins, tchoins
# Elle veut Louboutin-tin, tchoin
# Elle veut Mauboussin-ssin, tchoin
# Vrais ou faux seins-seins, tchoin
# Tchoin, tchoin, tchoin
#
# [Couplet 1]
# Je rentre avec DJ Mcfly et Lothy
# Tu t'assoies sur mes cuisses, t'es sur pilotis
# Balle dans l'chargeur est bien lotie
# Faut que je fasse rentrer des gros lo-ki
# J'ouvre une bouteille, le bouchon de liège saute
# Elle se retrouve dans l’œil du videur
# Ils se demandent si je prépare une sauce
# J't'emmène dans l'futur comme dans Les Visiteurs
# Je traîne à coté de ton derche
# Je sais qu't'es pas ma go go go
# Me demande pas c'que je cherche
# Y'a un Pokemon Go-go-go
# J'ouvre l'aileron du Panamera
# ...

# %%
artists = [
    "Damso",
    "Booba",
    "Niska",
    "MHD",
    "Vald",
    "Orelsan",
    "SCH",
    "PNL",
    "Kery James",
    "La fouine",
    "Nekfeu",
    "JuL",
    "Lorenzo",
    "Kaaris",
    "Wejdene",
    "Aya Nakamura",
    "JoeyStarr",
    "13 Organisé",
    "Maes",
    "Freeze Corleone",
    "Youssoupha",
    "Koba LaD",
    "Gradur",
    "Lacrim",
    "Heuss l'Enfoiré",
    "Kalash Criminel",
    "Ninho",
    "Mc Solaar",
    "Diam's",
    "Soprano",
    "Lomepal",
    "Kalash Criminel",
    "L’Algérino",
    "Suprême NTM",
    "Sexion d’Assaut",
    "Fatal Bazooka",
    "Black M",
    "Gims",
    "Sofiane",
    "Roméo Elvis",
    "Dosseh"
]

# %%
len(artists)
# Out:
# 40
