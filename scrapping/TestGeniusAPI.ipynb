# %%
import lyricsgenius
genius = lyricsgenius.Genius("BXGKadnQ5NCjtaEUJwfZ3SdVupRMyNW0B6endNpKPc3Awb46F8_4GpVzqe5mdw0M")
artist = genius.search_artist("Niska", max_songs=5, sort="popularity")
print(artist.songs)
# Out:
# Searching for songs by Niska...
#
# Song 1: "PSG (Matuidi Charo)"
# Song 2: "Réseaux"
# Song 3: "Salé"
# Song 4: "Carjack Chiraq"
# Song 5: "Chasse à l’homme (#KeDuSal 2)"
#
# Reached user-specified song limit (5).
# Done. Found 5 songs.
# [('PSG (Matuidi Charo)', 'Niska'), ('Réseaux', 'Niska'), ('Salé', 'Niska'), ('Carjack Chiraq', 'Niska'), ('Chasse à l’homme (#KeDuSal 2)', 'Niska')]

# %%
from PIL import Image
import requests
from io import BytesIO

response = requests.get(artist.image_url)
img = Image.open(BytesIO(response.content))

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=835x835 at 0x29DBC845610>

# %%
song = genius.search_song("Réseaux", artist.name)
print(song.lyrics)
# Out:
# Searching for "Réseaux" by Niska...
# Done.
# [Paroles de "Réseaux"]
#
# [Pré-Refrain]
# Skrt
# , pouloulou
# Skrt, pouloulou
# Skrt, pouloulou
# Skrt, pouloulou
#
# [Refrain]
# Posé, j'suis sous Jack dans mon bendo
#  (
# pouloulou
# )
# J'fais repérage de femmes sur les réseaux
#  (
# pouloulou
# )
# J'ai vu ses lolos
#  (
# vu ses 'eins
# , pouloulou
# )
# Elle m'a pas follow back quand je l'ai follow
#  (
# pouloulou
# )
# Elle fait la go qui connaît pas Charo (
# bye, bye, bye
# )
# Elle m'a vu à la télé, elle a dansé ma choré' (
# Matuidi charo
# )
# Elle fait la go qui connaît pas Charo (
# bye, bye, bye
# )
# Elle m'a vu à la télé, elle a dansé ma choré'
#
# [Couplet 1]
# Jamais j'ai vendu la mèche
#  (
# jamain
# )
# Depuis tit-pe j'ai connu la dèche
# Chez nous le client est geush
# Et si on t'connaît pas, bah le taro est reuch
#  (
# voilà
# )
# Ça galère, j'monte dans mon bolide
# J'balance du son à fond
# ,
# j'roule dans la ville entière
# ...

# %%
artists = [
    "Damso",
    "Booba",
    "Niska",
    "MHD",
    "Vald",
    "Orelsan",
    "SCH",
    "PNL",
    "Kery James",
    "La fouine",
    "Nekfeu",
    "JuL",
    "Lorenzo",
    "Kaaris",
    "Wejdene",
    "Aya Nakamura",
    "JoeyStarr",
    "13 Organisé",
    "Maes",
    "Freeze Corleone",
    "Youssoupha",
    "Koba LaD",
    "Gradur",
    "Lacrim",
    "Heuss l'Enfoiré",
    "Kalash Criminel",
    "Ninho",
    "Mc Solaar",
    "Diam's",
    "Soprano",
    "Lomepal",
    "Kalash Criminel",
    "L’Algérino",
    "Suprême NTM",
    "Sexion d’Assaut",
    "Fatal Bazooka",
    "Black M",
    "Gims",
    "Sofiane",
    "Roméo Elvis",
    "Dosseh"
]

# %%
len(artists)
# Out:
# 41
