# %%
import lyricsgenius
import json
import re
import string
import os
import unidecode

from collections import Counter, OrderedDict

string.punctuation+='’'

# %%
genius = lyricsgenius.Genius("BXGKadnQ5NCjtaEUJwfZ3SdVupRMyNW0B6endNpKPc3Awb46F8_4GpVzqe5mdw0M")

# %%
def process_lycrics(lyrics):
    lyrics = lyrics.lower()
    lyrics = unidecode.unidecode(lyrics)
    lyrics = re.sub(r"\[(.*?)\]", " ",lyrics)
    lyrics = re.sub('[%s]' % re.escape(string.punctuation), " ",  lyrics)
    lyrics = re.sub("\n", " ", lyrics)
    lyrics = lyrics.split(" ")
    
    return  [l for l in lyrics if l != '' and l != ' ' ]

# %%
artists = ["Damso",
        "Booba",
        "Kaaris",
        "13 Organisé",
          "Koba LaD",
          "Aya Nakamura",
          "Vald",
          "JuL"]

# %%
NUM_LYRYCS = 20000
MAX_SONGS = 50
ARTIST_FOLDER = "artists"

if not os.path.exists(ARTIST_FOLDER):
    os.makedirs(ARTIST_FOLDER)

for artist_name in artists:
    artist_dict = {}
    artist = genius.search_artist(artist_name, max_songs=MAX_SONGS, sort="popularity", get_full_info=False)
    artist_dict["name"] = artist.name
    artist_dict["image_url"] = artist.image_url
        
    vocab = []
    for song in artist.songs:
        vocab.extend(process_lycrics(song.lyrics))
        
    if len(vocab) >= NUM_LYRYCS:
        print(f"{artist.name} : OK")
        
    vocab = vocab[0:NUM_LYRYCS]
    artist_dict["vocab_length"] = len(set(vocab))
    artist_dict["vocab"] = Counter(vocab)
    
    with open(os.path.join(ARTIST_FOLDER, artist.name.replace(" ", "_") + ".json"), "w") as file:  
        json.dump(artist_dict, file)
# Out:
# Searching for songs by Damso...
#
# Song 1: "Feu de bois"
# Song 2: "Amnésie"
# Song 3: "Θ. Macarena"
# Song 4: "Γ. Mosaïque solitaire"
# Song 5: "N. J Respect R"
# Song 6: "Ε. Signaler"
# Song 7: "Autotune"
# Song 8: "Ζ. Kietu"
# Song 9: "BruxellesVie"
# Song 10: "Α. Nwaar Is The New Black"
# Song 11: "Ipséité"
# Song 12: "Paris c’est loin"
# Song 13: "Δ. Dieu ne ment jamais"
# Song 14: "Smog"
# Song 15: "Julien"
# Song 16: "Débrouillard"
# Song 17: "Ξ. Une âme pour deux"
# Song 18: "Baltringue"
# Song 19: "Graine de sablier"
# Song 20: "Humains"
# Song 21: "Tueurs"
# Song 22: "B. #QuedusaalVie"
# Song 23: "Silence"
# Song 24: "DEUX TOILES DE MER"
# Song 25: "60 années"
# Song 26: "Festival de rêves"
# Song 27: "Dix leurres"
# Song 28: "Peur d’être sobre"
# Song 29: "Périscope"
# Song 30: "Κ. Kin la belle"
# Song 31: "CQFD"
# Song 32: "William"
# Song 33: "Introduction (Damso / Lithopédion)"
# Song 34: "Λ. Lové"
# Song 35: "QuedelaVie"
# Song 36: "Exutoire"
# Song 37: "Η. Gova"
# Song 38: "LIFE LIFE"
# Song 39: "Noir meilleur"
# Song 40: "Fais-moi un Vie"
# Song 41: "BXL ZOO"
# Song 42: "Ι. Peur d’être père"
# Song 43: "Œveillé"
# Song 44: "Perplexe"
# Song 45: "Μ. Noob Saibot"
# Song 46: "Même issue"
# Song 47: "Beautiful"
# Song 48: "TieksVie"
# Song 49: "Monde"
# Song 50: "CŒUR EN MIETTES"
#
# Reached user-specified song limit (50).
# Done. Found 50 songs.
# Damso : OK
# Searching for songs by Booba...
#
# Song 1: "92i Veyron"
# Song 2: "Kalash"
# Song 3: "DKR"
# Song 4: "A.C. Milan"
# Song 5: "Scarface"
# Song 6: "Validée"
# Song 7: "Petite fille"
# Song 8: "Caramel"
# Song 9: "Tombé pour elle"
# Song 10: "Turfu"
# Song 11: "Pinocchio"
# Song 12: "Wesh Morray"
# Song 13: "OKLM"
# Song 14: "Parlons peu"
# Song 15: "Friday"
# Song 16: "113"
# Song 17: "Génération Assassin"
# Song 18: "RTC"
# Song 19: "Trône"
# Song 20: "Pitbull"
# Song 21: "3G"
# Song 22: "LVMH"
# Song 23: "E.L.E.P.H.A.N.T"
# Song 24: "Tony Sosa"
# Song 25: "Attila"
# Song 26: "Futur"
# Song 27: "La mort leur va si bien"
# Song 28: "Pirates"
# Song 29: "Salside"
# Song 30: "Paname"
# Song 31: "Maître Yoda"
# Song 32: "Ridin’"
# Song 33: "Une vie"
# Song 34: "Drapeau noir"
# Song 35: "4G"
# Song 36: "JAUNÉ"
# Song 37: "T.L.T (Clash VS La Fouine)"
# Song 38: "Daniel Sam"
# Song 39: "Comme une étoile"
# Song 40: "C’est la vie"
# Song 41: "D.U.C"
# Song 42: "Nougat"
# Song 43: "PGP"
# Song 44: "Freestyle Couvre Feu / OKLM"
# Song 45: "Comme les autres"
# Song 46: "Boulbi"
# Song 47: "Walabok"
# Song 48: "Bakel City Gang"
# Song 49: "Terrain"
# Song 50: "2Pac"
#
# Reached user-specified song limit (50).
# Done. Found 50 songs.
# Booba : OK
# Searching for songs by Kaaris...
#
# Song 1: "Zoo"
# Song 2: "Or Noir"
# Song 3: "Tchoin"
# Song 4: "Sevrak"
# Song 5: "Bouchon de liège"
# Song 6: "Paradis ou Enfer"
# Song 7: "63"
# Song 8: "Blow"
# Song 9: "Bizon"
# Song 10: "Chargé"
# Song 11: "S.E.V.R.A.N"
# Song 12: "Binks"
# Song 13: "Je bibi"
# Song 14: "Bling bling"
# Song 15: "C’est la base"
# Song 16: "Nador"
# Song 17: "Le bruit de mon âme"
# Song 18: "Dès le départ"
# Song 19: "Boyz N The Hood"
# Song 20: "Pas de remède"
# Song 21: "Crystal"
# Song 22: "Sombre"
# Song 23: "Terrain"
# Song 24: "Comme Gucci Mane"
# Song 25: "Ciroc"
# Song 26: "Bébé"
# Song 27: "L.E.F"
# Song 28: "Il a accouché de sa propre fin"
# Song 29: "Talsadoum"
# Song 30: "Diarabi"
# Song 31: "80 ZETREI"
# Song 32: "MBM"
# Song 33: "À l’heure"
# Song 34: "Poussière"
# Song 35: "Pablito"
# Song 36: "Intro"
# Song 37: "Zone de transit"
# Song 38: "Tu me connais"
# Song 39: "Dozo"
# Song 40: "À la barrière"
# Song 41: "Houdini"
# Song 42: "Kadirov"
# Song 43: "Juste"
# Song 44: "Plus rien"
# Song 45: "2 et demi"
# Song 46: "Magnum"
# Song 47: "Goulag"
# Song 48: "Octogone"
# Song 49: "Bon qu’à ça"
# Song 50: "4Matic"
#
# Reached user-specified song limit (50).
# Done. Found 50 songs.
# Kaaris : OK
# Searching for songs by 13 Organisé...
#
# Song 1: "Bande organisée"
# Song 2: "L’étoile sur le maillot"
# Song 3: "13 balles"
# Song 4: "War Zone"
# Song 5: "Je suis Marseille"
# Song 6: "Combien"
# Song 7: "Ma gadji"
# Song 8: "Tout a changé"
# Song 9: "C’est maintenant"
# Song 10: "Miami Vice"
# Song 11: "Partout c’est la même"
# Song 12: "Heat"
# Song 13: "La nuit"
# Song 14: "Bonus*"
# Done. Found 14 songs.
# Searching for songs by Koba LaD...
#
# Song 1: "RR 9.1"
# Song 2: "Ténébreux #1"
# Song 3: "Train de vie"
# Song 4: "La C"
# Song 5: "7 sur 7"
# Song 6: "Matin"
# Song 7: "Quotidien"
# Song 8: "Chambre 122"
# Song 9: "Oyé"
# Song 10: "Ténébreux #4"
# Song 11: "Cellophané"
# Song 12: "Guedro"
# Song 13: "Rentable"
# Song 14: "Ténébreux #2"
# Song 15: "Mortel"
# Song 16: "FeFe"
# Song 17: "Four"
# Song 18: "Moments durs"
# Song 19: "Pour toi"
# Song 20: "Aventador"
# Song 21: "Ténébreux #3"
# Song 22: "Honey"
# Song 23: "Suge"
# Song 24: "Marie"
# Song 25: "J’encaisse"
# Song 26: "Double D"
# Song 27: "Amitiés gâchées"
# Song 28: "R44"
# Song 29: "Tout"
# Song 30: "RR"
# Song 31: "Ça ira mieux demain"
# Song 32: "Recul"
# Song 33: "Seven Binks"
# Song 34: "Ténébreux #5"
# Song 35: "La détaille"
# Song 36: "Malhonnête"
# Song 37: "Mélange"
# Song 38: "#Freestyle2 (Seven Binks)"
# Song 39: "Demain j’arrête"
# Song 40: "C’est moi"
# Song 41: "ORgueilleux"
# Song 42: "Koba du 7"
# Song 43: "OKLM Freestyle"
# Song 44: "Quadrillé"
# Song 45: "Intro"
# Song 46: "Quand j’étais petit"
# Song 47: "Everyday"
# Song 48: "Le magot"
# Song 49: "Rachète"
# Song 50: "J’en veux"
#
# Reached user-specified song limit (50).
# Done. Found 50 songs.
# Koba LaD : OK
# Searching for songs by Aya Nakamura...
#
# Song 1: "Djadja"
# Song 2: "Pookie"
# Song 3: "Copines"
# Song 4: "Comportement"
# Song 5: "40%"
# Song 6: "La dot"
# Song 7: "Jolie nana"
# Song 8: "Sucette"
# Song 9: "Pookie - Capo Plaza Remix"
# Song 10: "Djadja (Maluma Remix)"
# Song 11: "Oula"
# Song 12: "J’ai mal"
# Song 13: "Oumou Sangaré"
# Song 14: "Le passé"
# Song 15: "Djadja (Loredana Remix)"
# Song 16: "Super-héros"
# Song 17: "Oublier"
# Song 18: "Fuego"
# Song 19: "Whine Up"
# Song 20: "Pompom"
# Song 21: "Brisé"
# Song 22: "Gangster"
# Song 23: "Ça fait mal"
# Song 24: "Pookie (Remix)"
# Song 25: "J’ai mal part. 2"
# Song 26: "Faya"
# Song 27: "Angela"
# Song 28: "Monaco"
# Song 29: "Sucette (Remix)"
# Song 30: "Dans ma bulle"
# Song 31: "Love"
# Song 32: "Problèmes"
# Song 33: "Gang"
# Song 34: "Idiot"
# Song 35: "Je n’ai pas besoin de toi"
# Song 36: "Cadeau"
# Song 37: "Claqué"
# Song 38: "Karma"
# Song 39: "Drogué"
# Song 40: "Orphelin"
# Song 41: "Soldat"
# Song 42: "Réponds"
# Song 43: "Jalousie"
# Song 44: "Soirée parisienne"
# Song 45: "Si tu savais"
# Song 46: "Papys"
# Song 47: "Moi"
# Song 48: "Doudou"
# Song 49: "Debout"
# Song 50: "Djadja (Afro B Remix)"
#
# Reached user-specified song limit (50).
# Done. Found 50 songs.
# Aya Nakamura : OK
# Searching for songs by Vald...
#
# Song 1: "Désaccordé"
# Song 2: "Vitrine"
# Song 3: "Eurotrap"
# Song 4: "Bonjour"
# Song 5: "Journal perso II"
# Song 6: "Gris"
# Song 7: "Je t’aime"
# Song 8: "Megadose"
# Song 9: "Ma meilleure amie"
# Song 10: "Résidus"
# Song 11: "Trophée"
# Song 12: "Selfie"
# Song 13: "Réflexions basses"
# Song 14: "Dragon"
# Song 15: "Possédé"
# Song 16: "Deviens génial"
# Song 17: "Primitif"
# Song 18: "Par toutatis"
# Song 19: "Seum"
# Song 20: "Offshore"
# Song 21: "Si j’arrêtais"
# Song 22: "Journal perso"
# Song 23: "Strip"
# Song 24: "Kid Cudi"
# Song 25: "Halloween"
# Song 26: "Urbanisme"
# Song 27: "Gizeh"
# Song 28: "Rappel"
# Song 29: "L.D.S"
# Song 30: "Promesse"
# Song 31: "Rituel"
# Song 32: "Infanticide"
# Song 33: "NQNTMQMQMB"
# Song 34: "Ce monde est cruel"
# Song 35: "Blanc"
# Song 36: "Ignorant"
# Song 37: "No friends"
# Song 38: "Neo"
# Song 39: "Acacia"
# Song 40: "Rechute"
# Song 41: "ASB"
# Song 42: "Dernier retrait"
# Song 43: "Autiste"
# Song 44: "Iencli"
# Song 45: "Totem"
# Song 46: "Pensionman"
# Song 47: "Jentertain"
# Song 48: "Poches pleines"
# Song 49: "CQFD"
# Song 50: "Pourquoi"
#
# Reached user-specified song limit (50).
# Done. Found 50 songs.
# Vald : OK
# Searching for songs by JuL...
#
# Song 1: "J’oublie tout"
# Song 2: "Tchikita"
# Song 3: "Tu la love"
# Song 4: "Dans ma paranoïa"
# Song 5: "My World (Barbie Girl Remix)"
# Song 6: "Wesh alors"
# Song 7: "Sors le cross volé"
# Song 8: "Lova"
# Song 9: "Comme d’hab"
# Song 10: "Dans mon del"
# Song 11: "Tout seul"
# Song 12: "En Y"
# Song 13: "Toto et Ninetta"
# Song 14: "Au quartier"
# Song 15: "Amnésia"
# Song 16: "Mon bijou"
# Song 17: "Mon Amour"
# Song 18: "Le sang"
# Song 19: "Ma jolie"
# Song 20: "Mama"
# Song 21: "Ils Sont Jaloux"
# Song 22: "Encore Des Paroles"
# Song 23: "Malade"
# Song 24: "On m’appelle l’ovni"
# Song 25: "Briganter"
# Song 26: "T’es pas le seul"
# Song 27: "La Classe"
# Song 28: "Pourquoi tu me fais le gros"
# Song 29: "Coucou"
# Song 30: "Señora"
# Song 31: "Mercé (Qu’est-ce qui se passe ?)"
# Song 32: "Lady"
# Song 33: "Oubliez-Moi"
# Song 34: "Elle et l’autre"
# Song 35: "La fusée"
# Song 36: "Anti-BDH"
# Song 37: "Jeune de cité"
# Song 38: "Dans La Légende"
# Song 39: "Mamasita"
# Song 40: "C’est trop"
# Song 41: "Grillé"
# Song 42: "On Est Trop"
# Song 43: "Je vais t’oublier"
# Song 44: "Elle te balade"
# Song 45: "Dans Mon Coeur"
# Song 46: "Dans L’appart"
# Song 47: "Émotions"
# Song 48: "Avant la douane"
# Song 49: "Je Peux Pas"
# Song 50: "Winners"
#
# Reached user-specified song limit (50).
# Done. Found 50 songs.
# JuL : OK
